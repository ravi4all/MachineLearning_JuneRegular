# %% [markdown]
# # K-Means Clustering

# %%
# Step 1 - Pick K random points as cluster centers called centroids.
# Step 2 - Assign each xi to nearest cluster by calculating its distance to each centroid.
# Step 3 - Find new cluster center by taking the average of the assigned points.
# Step 4 - Repeat Step 2 and 3 until none of the cluster assignments change.

# %% [markdown]
# # Import Modules

# %%
# Modules

# %% [markdown]
# # Read Data

# %%
# Read Data
# Out:
# (3000, 2)
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729

# %% [markdown]
# # Get the values and plot them

# %%
# Get X1 and X2
# Scatter Plot

# %% [markdown]
# # Calculate Distance

# %%
# Euclidean Distance
# Use numpy.linalg

# %% [markdown]
# # Initialise clusters

# %%
# Number of clusters

# X_coordinates of random centroids

# Y_coordinates of random centroids

# %% [markdown]
# # Plot clusters

# %%
# Plot along with the Centroids

# %% [markdown]
# # Find New Cluster Center

# %%
# To store the value of centroids when it updates

# Cluster Lables(0, 1, 2)

# Error func. - Distance between new centroids and old centroids

# Start Loop and run till the error becomes zero

# Assign each value to its closest cluster

# print("Distance is",distances)
# print("Cluster is",cluster)

# Store the old centroid values

# Find the new centroids by taking the average value

# %% [markdown]
# # Plot final clusters with centroids
