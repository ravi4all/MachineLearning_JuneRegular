# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Numpy Introduction

# %%
x = np.array([i for i in range(1,11)])
y = np.random.randint(5,5000,10)

# %%
print(len(x), len(y))
# Out:
# 10 10

# %%
plt.plot(x,y)
plt.show()
